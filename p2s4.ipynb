# %%
Y.t = 10 + arima.sim(list(order=c(0,0,1), ma=0.5), n = 100)
mean(Y.t)
mean(Y.t) - 2.576 * 0.15
mean(Y.t) + 2.576 * 0.15
Y.t = 10 + arima.sim(list(order=c(0,0,1), ma=-0.5), n = 100)
mean(Y.t)
mean(Y.t) - 2.576 * 0.15
mean(Y.t) + 2.576 * 0.15
# Out:
# [1] 9.861229
# [1] 9.474829
# [1] 10.24763
# [1] 9.931833
# [1] 9.545433
# [1] 10.31823
