# %%
wn <- rnorm(500)
ar1 = arima.sim(500, model=list(ar=0.6))

# %%
Box.test(wn, lag=5, type='Ljung-Box')

# %%
Box.test(ar1, lag=5, type='Ljung-Box')

# %%
Box.test(wn, lag=500, type='Ljung-Box')

# %%
Box.test(wn, lag=100, type='Ljung-Box')

# %%
Box.test(ar1, lag=100, type='Ljung-Box')

# %%
Box.test(ar1, lag=100, fitdf=1, type='Ljung-Box')

# %%
help(Box.test)
