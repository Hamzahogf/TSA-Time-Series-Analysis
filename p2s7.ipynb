# %%
library(TSA)
data(prescrip)
plot(prescrip)
# Out:
# Attachement du package : 'TSA'
#
#
# Les objets suivants sont masqués depuis 'package:stats':
#
#     acf, arima
#
#
# L'objet suivant est masqué depuis 'package:utils':
#
#     tar
# plot without title

# %%
diff.1 <- diff(prescrip)
plot(diff.1)
# Out:
# plot without title

# %%
mean(diff.1)

# %%
hist(diff.1, breaks=20)
hist(diff.1, breaks=10)

# %%
shapiro.test(diff.1)

# %%
qqnorm(diff.1)

# %%
acf(diff.1)

# %%
# great 
pacf(diff.1)

# %%
# nice
library(tseries)
diff_sign <- factor(ifelse(diff.1 > 0, "+","-"))

# %%
runs.test(diff_sign)

# %%
adf.test(diff.1)
